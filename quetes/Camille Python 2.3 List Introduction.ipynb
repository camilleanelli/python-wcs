# %% [markdown]
# # Mission 1

# %% [markdown]
# For each cell, execute the code and answer the question before moving on to the next.

# %%
names = ["Fredy", "Nicolas", "Alexandre"]

for i in enumerate(names):
  print(i)
# Out:
# (0, 'Fredy')
# (1, 'Nicolas')
# (2, 'Alexandre')

# %% [markdown]
# 1. What type of object is returned as output?
# Hint: You can use `type(i)`.

# %% [markdown]
# Answer:
#
# Here the type of output returned is a tuple.

# %%
type(i)
# Out:
# tuple

# %%
for i, val in enumerate(names):
  print(val)
# Out:
# Fredy
# Nicolas
# Alexandre

# %% [markdown]
# 2. What does `i` correspond to?
# What does `val` correspond to?
# Why is it so?
#
# Answer:
#
# - `i` correspond to the index
# -  `val` correspond to the value.
# - When enumerate is called, we can loop on index and values of the object.

# %%
for val, i in enumerate(names):
  print(val)
# Out:
# 0
# 1
# 2

# %% [markdown]
# 3. This time, `i` returns first names and `val` returns numbers. Why is it so?

# %% [markdown]
# *Answer*:
#
# Because you can give any variable name you want. The index will be in first position and the value will be in second position.
#
#
# For instance, `for tado, tada in enumerate(names):` would be interpreted the same way, but it is not the good way to be understandable.

# %% [markdown]
# 4. What does the built in function `enumerate` do?
# In what cases can it be useful?

# %% [markdown]
# Answer:
#
# - This function converts the object in an enumerate object. (just during the programm)
# - It is usefull when you need to loop on index and values of an objects like lists, tuples, and string.

# %% [markdown]
# # Mission 2

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]

test_list[8] = "Marshall"

test_list
# Out:
# ['Hi', 'my', 'name', 'is', 'hi', 'my', 'name', 'is', 'Marshall']

# %% [markdown]
# 1. What does the 8 in square brackets mean?
# What action has been performed?

# %% [markdown]
# Answer:
#
# - `8` in square brackets means the index at position 8.
# - The action performed is to find and display the element at the index 8 from the list `test_list`

# %%
for i in range(4):
  print(test_list[i])
# Out:
# Hi
# my
# name
# is

# %% [markdown]
# 2. What does `range(4)` mean?
# Why are only the first 4 elements of `test_list` displayed?

# %% [markdown]
# Answer:
#
# - `range(4)` is a range starting by 0, and ending at 4, where 4 is NOT included.
# - The first 4 elements are displayed because it starts by 0 and 4 is not included.

# %%
type(range(4))
print(range(4))
# Out:
# range(0, 4)

# %%
for i in range(2, 8, 2):
  print(test_list[i])
# Out:
# name
# hi
# name

# %% [markdown]
# 3. What does `range(2,8,2)` mean ?
# Why are only the elements 'name', 'hi' and 'name' displayed?

# %% [markdown]
# Answer:
#
# - `range(2, 8, 2)` is a range between 2 and 8, with a step of 2.
# - The elements are displayed like this because of the step, so we have one word every 2 steps.

# %% [markdown]
# # Mission 3

# %%
numbers = [2,3,1,5,9]

for i in range(10,15):
  numbers.append(i)

numbers
# Out:
# [2, 3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 1. What does `range(10,15)` mean ?
#   What is the purpose of the method `append()` ?

# %% [markdown]
# Answer:
#
# - `range(10, 15)` is a range of numbers between 10 and 15 where 15 is NOT included.
# - `append()` is used to add new elements inside the list.

# %% [markdown]
# 2. What is the purpose of the `del` command?

# %% [markdown]
# Answer:
#
# `del` is used to delete object

# %% [markdown]
# # Mission 4

# %%
import random

random.randint(0,10)
# Out:
# 5

# %% [markdown]
# 1. What can the method `randint()` do ?

# %% [markdown]
# Answer:
#
# `randint()` returns a random integer between 2 values, both included. It takes 2 arguments, the start value and the end value.

# %%
import random
random.randint(3, 100)
# Out:
# 77

# %% [markdown]
# 2. What can the method `.insert()` do ?
# You must answer using the terms 'parameter' and 'argument'.

# %% [markdown]
# Answer:
#
# - `.insert()` allows us to insert an element at a specific position inside a list asking parameted.
# - It takes 2 arguments the position and the element to insert.

# %% [markdown]
# # Mission 5

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]

test_list = " ".join(test_list)

test_list
# Out:
# 'Hi my name is hi my name is chickychicky'

# %% [markdown]
# 1. What can the `.join()` method do?
# What is the type of `test_list` before using `.join()`?
# What is the type of `test_list` after using `.join()`?

# %% [markdown]
# Answer:
#
# - `.join()` is used to transform an iterable into a string with specific delimiters like space or characters.
# This method must be applied on a string like so `";".join()`.
# - `test_list` was a list before using `join()` and became a `string` after.

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"

christmas.split()
print(type(christmas))
# Out:
# <class 'str'>

# %% [markdown]
# 2. What can the `.split()` method do?
# What is the type of `christmas` before using `.split()`?
# What is the type of `christmas` after using `.split()`?

# %% [markdown]
# Answer:
#
# - `split()` converts a string into a list. It can take 0 or 1 argument, the delimiter for example `,`. In that case, it could be an entire phrase instead of a single word.
# - `christmas` was a string before using the method and stay as a string because the object `string` is immutable.

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fait à chaque fois. C'est la vie"


christmas.split("à")
# Out:
# ["Noël c'est bien, mais attention ",
#  ' ne pas manger trop de chocolat. On le sait, mais on le fait ',
#  " chaque fois. C'est la vie"]

# %% [markdown]
# 3. Why does the `.split()` method split the `string` into 3 elements?

# %% [markdown]
# Answer:
#
# Because we can see that only 3 elements are separated by `à` and the method takes this delimiter in argment.
