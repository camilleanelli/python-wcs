# %% [markdown]
# # Type

# %% [markdown]
# 1. Dans la cellule de code ci-dessous, quel est, pour chaque cellule, le type de chaque objet ?
# `indice`: vous pouvez utiliser `type(x)` pour le révéler.

# %% [markdown]
# 1.1

# %%
count = 5
print(type(count))
# Out:
# <class 'int'>

# %% [markdown]
# 1.2

# %%
greeting = "Hello World"
print(type(greeting))
# Out:
# <class 'str'>

# %% [markdown]
# 1.3

# %%
price = 2.5
print(type(price))
# Out:
# <class 'float'>

# %% [markdown]
# 1.4

# %%
color_palette = ["mintcream", "burlywood", "salmon"]
print(type(color_palette))
# Out:
# <class 'list'>

# %% [markdown]
# 1.5

# %%
colors = ("mintcream", "burlywood", "salmon")
print(type(colors))
# Out:
# <class 'tuple'>

# %% [markdown]
# 1.6

# %%
person_info = {"name": "Jules César", "Job": "Musician", "age": 55}
print(type(person_info))
# Out:
# <class 'dict'>

# %% [markdown]
# 1.7

# %%
is_active = True
print(type(is_active))
# Out:
# <class 'bool'>

# %% [markdown]
# 2. Maintenant, vous allez devoir convertir des objets d'un certain type, en un autre type d'objet.
# C'est parti !

# %% [markdown]
# 2.1 Convertissez count en float.

# %%
count = 5
float(count)
# Out:
# 5.0

# %% [markdown]
# 2.2 Convertissez price en int

# %%
price = 5.4
int(price)
# Out:
# 5

# %% [markdown]
# 2.3 Convertissez price en int

# %%
price = 5.6
int(price)
# Out:
# 5

# %% [markdown]
# 2.4 Que pouvez-vous remarquer ?

# %% [markdown]
# Réponse:

# %% [markdown]
# On peut constater que convertir un float en integer supprime les décimales ce qui peut être contraignant si on voulait arrondir.

# %% [markdown]
# 2.5 Trouvez le moyen d'arrondir temperature.

# %%
temperature = 5.6
result = round(temperature)
result
# Out:
# 6

# %% [markdown]
# 2.6 Après avoir arrondi temperature, est-ce que c'est toujours un `float` ?
# Réponse:
# Si on stoque la valeur obtenue dans une variable, alors la nouvelle valeur est de type integer.
# Mais si on vient vérifier la variabla `temperature` alors on obtient toujours un float.

# %% [markdown]
# 2.7 Ci-dessous, est-ce que height est un `int` ?

# %%
height = 6.0
type(height)
# Out:
# float

# %% [markdown]
# 2.8 Arrondissez pi avec 3 valeurs décimales.

# %%
pi = 3.14159265359
round(pi, 3)
# Out:
# 3.142

# %% [markdown]
# # Built-in Function

# %% [markdown]
# 3.1 Utilisez une [built-in function](https://docs.python.org/3/library/functions.html) pour compter le nombre de lettres dans l'objet de type `string` suivant:

# %%
greeting = "Hello World"
len(greeting)
# Out:
# 11

# %% [markdown]
# 3.2 Utilisez une built-in function pour compter le nombre d'éléments dans l'objet de type `list` suivant:

# %%
mixed_data = ["non", "pas", 1, "ni", 2, "ni", 3, "mais", 7.2132]
len(mixed_data)
# Out:
# 9

# %% [markdown]
# 3.3 Utilisez une built-in function sur une des deux variables pour que `resultat`  contienne une valeur positive.

# %%
positive_number = 4
negative_number = -5

resultat = positive_number + abs(negative_number)

# %% [markdown]
# 3.4 Utilisez une built-in function pour renvoyer la valeur minimum de la `list` suivante:

# %%
values = [3.2, 41, 2, 23, 7]
min(values)
# Out:
# 2

# %% [markdown]
# 3.5 Utilisez une built-in function pour renvoyer la somme des valeurs de la `list` suivante:

# %%
values = [3.2, 41, 2, 23, 7]
sum(values)
# Out:
# 76.2
