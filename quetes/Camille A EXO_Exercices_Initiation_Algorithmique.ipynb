# %% [markdown]
# # Exercices d'Initiation à l'Algorithmique avec du Pseudo-Code
# Ce notebook contient plusieurs exercices basiques d'algorithmique qui utilisent du pseudo-code. Vous pouvez essayer de les résoudre pour vous familiariser avec les concepts de base de l'algorithmie.
#
# ## Exercice 1 : Affichage de texte simple
# Écrire un pseudo-code qui affiche "Bonjour le monde".
#
# **Pseudo-code** :
# ```
# Début
#   print("Bonjour le monde")
# Fin
# ```
#
# ## Exercice 2 : Calcul de la somme de deux nombres
# Écrire un pseudo-code qui lit deux nombres, calcule leur somme et affiche le résultat.
#
# **Pseudo-code** :
# ```
# Début
#   a = 4
#   b = 5
#   resultat = a + b
#   print(resultat)
# Fin
# ```
#
# ## Exercice 3 : Vérification si un nombre est pair ou impair
# Écrire un pseudo-code qui vérifie si un nombre donné est pair ou impair.
#
# **Pseudo-code** :
# ```
# Début
#   if nombre % 2 == 0:
#       print("{nombre} est pair")
#   else:
#       print("{nombre} est impair")
# Fin
# ```
#
# ## Exercice 4 : Calcul de la factorielle d'un nombre
# Écrire un pseudo-code qui calcule la factorielle d'un nombre donné.
#
# **Pseudo-code** :
# ```
# Début
#   nombre = 5
#   nombres = list(range(1,6))
#   resultat = 1
#   for i in nombres:
#      resultat = i * resultat
#   print(resultat)
# Fin
# ```
#
# ## Exercice 5 : Afficher les premiers nombres naturels
# Écrire un pseudo-code qui affiche les N premiers nombres naturels, où N est un nombre donné par l'utilisateur.
#
# **Pseudo-code** :
# ```
# Début
#   n = input("Donner un nombre: ")
#   list_premiers = [2]
#   i = 3
#   tant que la liste est <= N
#   on veut verifier si i est premier naturel
#   si i n'est divisible par aucun des nombres d'avant
#   on le rajoute a la liste
#   on nettoi les doublons
#   on passe au nombre suivant
#
#   while len(list_premiers) <= n:
#       for nbr in list_premiers:
#           if i % nbr != 0
#           list_premiers.append(i)
#       list_premiers = list(dict.fromkeys(list_premiers))
#       i += 1
#
# Fin
# ```
